# %% [markdown]
# # Data Ingestion Pipeline Practice

# %%
# Create dataset files path

import os

os.makedirs("../data/text_files", exist_ok=True)
os.makedirs("../data/pdf_files", exist_ok=True)

# %% [markdown]
# ### Documents Structure with Langchain

# %%
from langchain_core.documents import Document

doc = Document(
    page_content = "Undrestand the documnets structure and its importance in RAG application.",
    metadata = {
        "source" : "example.txt",
        "pages" : 1,
        "authors" : "RAG",
        "Created_date" : "2026-05-11"
    }
)

doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'authors': 'RAG', 'Created_date': '2026-05-11'}, page_content='Undrestand the documnets structure and its importance in RAG application.')

# %% [markdown]
# ### Create and load single file with langchain

# %%
sample_text = {
    "../data/text_files/Introduction_to_Python.txt":"""Introduction to Python

Python is a high-level, interpreted programming language known for its simple syntax and readability. It was created by 
Guido van Rossum and first released in 1991. Python is widely used in software development, web applications, automation, 
and scientific computing because it allows programmers to write clean and efficient code.

One of Python’s greatest strengths is its versatility. Developers use it for building websites, analyzing data, creating 
artificial intelligence systems, and automating repetitive tasks. Python supports multiple programming styles, including 
procedural, object-oriented, and functional programming, making it suitable for both beginners and experienced programmers.

Python also has a large global community and a rich collection of libraries and frameworks. Tools such as Django for 
web development and TensorFlow for machine learning help developers create powerful applications quickly. Because of its ease 
of learning and broad applications, Python remains one of the most popular programming languages in the world.

Key Features of Python
 - Simple and easy-to-read syntax
 - Interpreted language with fast development cycle
 - Cross-platform compatibility
 - Large standard library and third-party modules
 - Supports object-oriented programming
 - Strong community support
 - Widely used in AI, data science, and web development
 - Open-source and free to use

Overall

Python is a powerful and flexible programming language that is suitable for beginners and professionals alike. Its readability, 
extensive libraries, and wide range of applications make it an excellent choice for modern software development. From 
web development to artificial intelligence, Python continues to play a major role in the technology industry.
""",

    "../data/text_files/Machine_Learning_Basics.txt":"""Machine Learning Basics

Machine Learning (ML) is a branch of Artificial Intelligence that enables computers to learn from data and improve 
their performance without being explicitly programmed. Instead of following fixed instructions, machine learning systems 
identify patterns in data and make predictions or decisions based on those patterns. This technology is widely used in modern 
applications such as recommendation systems, image recognition, and voice assistants.

Machine learning works by training algorithms using large datasets. During training, the model analyzes the data, learns 
relationships, and adjusts itself to improve accuracy. Once trained, the model can process new data and provide 
predictions or classifications. Popular programming languages like Python and frameworks such as Scikit-learn are 
commonly used to build machine learning applications.

Types of Machine Learning
 - Supervised Learning
 - Unsupervised Learning
 - Reinforcement Learning
 - Semi-Supervised Learning
 - Deep Learning

Applications of Machine Learning

Machine learning is used in many industries to solve real-world problems efficiently. In healthcare, it helps diagnose 
diseases and predict patient outcomes. In finance, ML systems detect fraud and analyze market trends. E-commerce 
platforms use machine learning for personalized recommendations, while self-driving cars rely on it for object detection 
and navigation. As technology continues to evolve, machine learning is becoming an essential part of everyday life and modern innovation.
""",

    "../data/text_files/RAG_Basics.txt":"""RAG Basics

Retrieval-Augmented Generation (RAG) is an advanced AI technique that combines information retrieval with 
text generation. It enhances the capabilities of large language models by allowing them to access external 
knowledge sources before generating responses. Instead of relying only on pre-trained data, RAG systems search 
databases, documents, or websites to retrieve relevant information and produce more accurate and up-to-date answers.

RAG works in two main stages: retrieval and generation. In the retrieval stage, the system searches for relevant 
data from a knowledge base using similarity search or embeddings. In the generation stage, the retrieved information is 
passed to a language model, which generates a meaningful and context-aware response. Technologies such as LangChain and vector 
databases like Pinecone are commonly used to build RAG-based applications.

Types of RAG Systems
 - Naive RAG
 - Advanced RAG
 - Modular RAG
 - Hybrid RAG
 - Graph-based RAG

Applications of RAG

RAG is widely used in modern AI applications where accurate and updated information is important. It is commonly 
applied in chatbots, virtual assistants, customer support systems, and enterprise search tools. In healthcare and finance, 
RAG helps provide reliable answers from large document collections, while in education it supports intelligent tutoring systems. 
By combining retrieval and generation, RAG improves response quality, reduces hallucinations, and enables AI systems to deliver more 
trustworthy information.
"""
}

# Store the sample_text file

for filepath, content in sample_text.items():
    with open(filepath, "w", encoding="utf-8") as f:
        f.write(content)

print("Sample text files created.")
# Out:
# Sample text files created.

# %%
# Import and implement TextLoader
# from langchain.document_loaders import textLoader
from langchain_community.document_loaders import TextLoader

# Use langchain TextLoader to create structural documents for RAG
loader = TextLoader("../data/text_files/Introduction_to_Python.txt", encoding="utf-8")
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/Introduction_to_Python.txt'}, page_content='Introduction to Python\n\nPython is a high-level, interpreted programming language known for its simple syntax and readability. It was created by \nGuido van Rossum and first released in 1991. Python is widely used in software development, web applications, automation, \nand scientific computing because it allows programmers to write clean and efficient code.\n\nOne of Python’s greatest strengths is its versatility. Developers use it for building websites, analyzing data, creating \nartificial intelligence systems, and automating repetitive tasks. Python supports multiple programming styles, including \nprocedural, object-oriented, and functional programming, making it suitable for both beginners and experienced programmers.\n\nPython also has a large global community and a rich collection of libraries and frameworks. Tools such as Django for \nweb development and TensorFlow for machine learning help developers create powerful applications quickly. Because of its ease \nof learning and broad applications, Python remains one of the most popular programming languages in the world.\n\nKey Features of Python\n - Simple and easy-to-read syntax\n - Interpreted language with fast development cycle\n - Cross-platform compatibility\n - Large standard library and third-party modules\n - Supports object-oriented programming\n - Strong community support\n - Widely used in AI, data science, and web development\n - Open-source and free to use\n\nOverall\n\nPython is a powerful and flexible programming language that is suitable for beginners and professionals alike. Its readability, \nextensive libraries, and wide range of applications make it an excellent choice for modern software development. From \nweb development to artificial intelligence, Python continues to play a major role in the technology industry.\n')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

# Use langchain PDFLoader to create structural documnets for RAG
pdf_loader = PyMuPDFLoader("../data/pdf_files/AffectGPT - A New Dataset, Model, and Benchmark for Emotion Understanding with Multimodal Large Language Models.pdf")
pdf_doc = pdf_loader.load()
print(pdf_doc)
# Out:
# [Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T12:53:22+02:00', 'source': '../data/pdf_files/AffectGPT - A New Dataset, Model, and Benchmark for Emotion Understanding with Multimodal Large Language Models.pdf', 'file_path': '../data/pdf_files/AffectGPT - A New Dataset, Model, and Benchmark for Emotion Understanding with Multimodal Large Language Models.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T12:53:22+02:00', 'trapped': '', 'modDate': "D:20260509125322+02'00'", 'creationDate': "D:20260509125322+02'00'", 'page': 0}, page_content='Title: AffectGPT: A New Dataset, Model, and Benchmark for Emotion Understanding with \nMultimodal Large Language Models \nPublication Date: 2025 \nResearch Field: Multimodal Emotion Recognition (MER), Multimodal Large Language \nModels (MLLMs), Affective Computing \nKeywords: Emotion Understanding, Multimodal Learning, Large Language Models, Dataset \nConstruction, Benchmarking, Emotion Recognition \nPaper Type: Benchmark + Model + Dataset (combined research contribution paper) \nShort Summary \nThis paper introduces a comprehensive framework for advancing emotion understanding \nusing Multimodal Large Language Models (MLLMs). It proposes: \n1. A large-scale descriptive dataset (MER-Caption) with over 115K samples and \n~2,900 emotion categories. \n2. A novel multimodal model (AffectGPT) with enhanced fusion via pre-fusion \noperations. \n3. A unified evaluation benchmark (MER-UniBench) tailored to free-form emotional \nlanguage outputs. \nThe results demonstrate significant improvements (over 9%) compared to existing MLLMs \nacross multiple emotion recognition tasks. \nProblem & Motivation \nTraditional emotion recognition systems rely on discrete classification frameworks (e.g., \nEkman’s six emotions), which fail to capture: \n• \nThe diversity of emotional expressions \n• \nThe coexistence of multiple emotions \n• \nThe contextual and cultural nuances of human affect \nMoreover, existing limitations include: \n• \nLack of large-scale descriptive emotion datasets \n• \nInsufficient multimodal fusion strategies in current MLLMs \n• \nAbsence of evaluation benchmarks for free-form emotion descriptions \nThe motivation is to shift from closed-set classification to open-ended, natural language \nemotion understanding enabled by MLLMs. \nSolution Approach \nThe paper addresses the problem through three key components: \n1. Dataset: Construct MER-Caption using a model-led, human-assisted annotation \nstrategy.'), Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T12:53:22+02:00', 'source': '../data/pdf_files/AffectGPT - A New Dataset, Model, and Benchmark for Emotion Understanding with Multimodal Large Language Models.pdf', 'file_path': '../data/pdf_files/AffectGPT - A New Dataset, Model, and Benchmark for Emotion Understanding with Multimodal Large Language Models.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T12:53:22+02:00', 'trapped': '', 'modDate': "D:20260509125322+02'00'", 'creationDate': "D:20260509125322+02'00'", 'page': 1}, page_content='2. Model: Develop AffectGPT with pre-fusion multimodal integration to better \ncapture cross-modal interactions. \n3. Benchmark: Create MER-UniBench with custom evaluation metrics for free-form \noutputs. \nThis integrated approach targets both data limitations and model architecture \nweaknesses in existing systems. \nCore Contributions and Novelty \n• \nIntroduction of the largest multimodal descriptive emotion dataset (115K \nsamples, 2K+ emotion categories). \n• \nProposal of a model-led human-assisted annotation paradigm, balancing \nscalability and quality. \n• \nDevelopment of AffectGPT, which explicitly enhances multimodal fusion via pre ...

# %%
# CSV file loader
from langchain_community.document_loaders import CSVLoader

# Create CSV file path
os.makedirs("../data/csv_files", exist_ok=True)

csv_loader = CSVLoader("../data/csv_files/Task_3_and_4_Loan_Data.csv")
csv_doc = csv_loader.load()
csv_doc
# Out:
# [Document(metadata={'source': '../data/csv_files/Task_3_and_4_Loan_Data.csv', 'row': 0}, page_content='customer_id: 8153374\ncredit_lines_outstanding: 0\nloan_amt_outstanding: 5221.545193\ntotal_debt_outstanding: 3915.471226\nincome: 78039.38546\nyears_employed: 5\nfico_score: 605\ndefault: 0'),
#  Document(metadata={'source': '../data/csv_files/Task_3_and_4_Loan_Data.csv', 'row':
ndefault: 0'),
#  Document(metadata={'source': '../data/csv_files/Task_3_and_4_Loan_Data.csv', 'row': 985}, page_content='customer_id: 6416904\ncredit_lines_outstanding: 1\nloan_amt_outstanding: 2339.616825\ntotal_debt_outstanding: 4074.365765\nincome: 54017.84712\nyears_employed: 8\nfico_score: 642\ndefault: 0'),
#  Document(metadata={'source': '../data/csv_files/Task_3_and_4_Loan_Data.csv', 'row': 986}, page_content='customer_id: 4002168\ncredit_lines_outstanding: 5\nloan_amt_outstanding: 3687.063498\ntotal_debt_outstanding: 14737.18223\nincome: 61689.46931\nyears_employed: 6\nfico_score: 545\ndefault: 1'),
#  Document(metadata={'source': '../data/csv_files/Task_3_and_4_Loan_Data.csv', 'row': 987}, page_content='customer_id: 5784127\ncredit_lines_outstanding: 1\nloan_amt_outstanding: 4755.221685\ntotal_debt_outstanding: 7047.485527\nincome: 80099.40332\nyears_employed: 5\nfico_score: 626\ndefault: 0'),
#  Document(metadata={'source': '../data/csv_files/Task_3_and_4_Loan_Data.csv', 'row': 988}, page_content='customer_id: 2719478\ncredit_lines_outstanding: 1\nloan_amt_outstanding: 4092.350423\ntotal_debt_outstanding: 7401.668314\nincome: 78884.26598\nyears_employed: 5\nfico_score: 639\ndefault: 0'),
#  Document(metadata={'source': '../data/csv_files/Task_3_and_4_Loan_Data.csv', 'row': 989}, page_content='customer_id: 4624381\ncredit_lines_outstanding: 0\nloan_amt_outstanding: 4262.764327\ntotal_debt_outstanding: 6651.147311\nincome: 72306.77395\nyears_employed: 3\nfico_score: 709\ndefault: 0'),
#  Document(metadata={'source': '../data/csv_files/Task_3_and_4_Loan_Data.csv', 'row': 990}, page_content='customer_id: 5120326\ncredit_lines_outstanding: 0\nloan_amt_outstanding: 3854.431194\ntotal_debt_outstanding: 5235.235219\nincome: 57172.19861\nyears_employed: 4\nfico_score: 611\ndefault: 0'),
#  Document(metadata={'source': '../data/csv_files/Task_3_and_4_Loan_Data.csv', 'row': 991}, page_content='customer_id: 2528020\ncredit_lines_outstanding: 0\nloan_amt_outstanding: 3998.987343\ntotal_debt_outstanding: 5384.069421\nincome: 69102.80396\nyears_employed: 4\nfico_score: 733\ndefault: 0'),
#  Document(metadata={'source': '../data/csv_files/Task_3_and_4_Loan_Data.csv', 'row': 992}, page_content='customer_id: 1146826\ncredit_lines_outstanding: 1\nloan_amt_outstanding: 3988.563878\ntotal_debt_outstanding: 7287.83646\nincome: 56036.14865\nyears_employed: 3\nfico_score: 550\ndefault: 0'),
#  Document(metadata={'source': '../data/csv_files/Task_3_and_4_Loan_Data.csv', 'row': 993}, page_content='customer_id: 1006053\ncredit_lines_outstanding: 1\nloan_amt_outstanding: 4074.087343\ntotal_debt_outstanding: 6280.7637\nincome: 59854.96324\nyears_employed: 4\nfico_score: 648\ndefault: 0'),
#  Document(metadata={'source': '../data/csv_files/Task_3_and_4_Loan_Data.csv', 'row': 994}, page_content='customer_id: 6403706\ncredit_lines_outstanding: 0\nloan_amt_outstanding: 4516.391458\ntotal_debt_outstanding: 5726.787375\nincome: 55730.27928\nyears_employed: 3\nfico_score: 676\ndefault: 0'),
#  Document(metadata={'source': '../data/csv_files/Task_3_and_4_Loan_Data.csv', 'row': 995}, page_content='customer_id: 2346075\ncredit_lines_outstanding: 0\nloan_amt_outstanding: 5250.094385\ntotal_debt_outstanding: 4233.980876\nincome: 86137.04205\nyears_employed: 4\nfico_score: 574\ndefault: 0'),
#  Document(metadata={'source': '../data/csv_files/Task_3_and_4_Loan_Data.csv', 'row': 996}, page_content='customer_id: 6991491\ncredit_lines_outstanding: 5\nloan_amt_outstanding: 3508.423992\ntotal_debt_outstanding: 21307.0328\nincome: 71034.34755\nyears_employed: 5\nfico_score: 513\ndefault: 1'),
#  Document(metadata={'source': '../data/csv_files/Task_3_and_4_Loan_Data.csv', 'row': 997}, page_content='customer_id: 7122255\ncredit_lines_outstanding: 0\nloan_amt_outstanding: 2274.747659\ntotal_debt_outstanding: 435.7796619\nincome: 43577.96619\nyears_employed: 4\nfico_score: 628\ndefault: 0'),
#  Document(metadata={'source': '../data/csv_files/Task_3_and_4_Loan_Data.csv', 'row': 998}, page_content='customer_id: 1770145\ncredit_lines_outstanding: 0\nloan_amt_outstanding: 2290.148099\ntotal_debt_outstanding: 395.8584593\nincome: 39585.84593\nyears_employed: 2\nfico_score: 651\ndefault: 0'),
#  Document(metadata={'source': '../data/csv_files/Task_3_and_4_Loan_Data.csv', 'row': 999}, page_content='customer_id: 7059831\ncredit_lines_outstanding: 2\nloan_amt_outstanding: 2854.198163\ntotal_debt_outstanding: 5053.30323\nincome: 41883.44564\nyears_employed: 5\nfico_score: 571\ndefault: 0'),
#  ...]

# %% [markdown]
# ### Use Directory Loader to Load and Create Structural Documents

# %%
# Loader to Load and Create Structural Documents of All Files in a Directory Simultaneously
from langchain_community.document_loaders import DirectoryLoader

# Load all txt files in directory
dir_loader = DirectoryLoader(
    "../data/text_files",
    glob = "**/*.txt", # Patern to match all files
    loader_cls = TextLoader, # Loader class to use 
    loader_kwargs = {"encoding":"utf-8"},
    show_progress = False
)

txt_docs = dir_loader.load()
txt_docs
# Out:
# [Document(metadata={'source': '../data/text_files/Machine_Learning_Basics.txt'}, page_content='Machine Learning Basics\n\nMachine Learning (ML) is a branch of Artificial Intelligence that enables computers to learn from data and improve \ntheir performance without being explicitly programmed. Instead of following fixed instructions, machine learning systems \nidentify patterns in data and make predictions or decisions based on those patterns. This technology is widely used in modern \napplications such as recommendation systems, image recognition, and voice assistants.\n\nMachine learning works by training algorithms using large datasets. During training, the model analyzes the data, learns \nrelationships, and adjusts itself to improve accuracy. Once trained, the model can process new data and provide \npredictions or classifications. Popular programming languages like Python and frameworks such as Scikit-learn are \ncommonly used to build machine learning applications.\n\nTypes of Machine Learning\n - Supervised Learning\n - Unsupervised Learning\n - Reinforcement Learning\n - Semi-Supervised Learning\n - Deep Learning\n\nApplications of Machine Learning\n\nMachine learning is used in many industries to solve real-world problems efficiently. In healthcare, it helps diagnose \ndiseases and predict patient outcomes. In finance, ML systems detect fraud and analyze market trends. E-commerce \nplatforms use machine learning for personalized recommendations, while self-driving cars rely on it for object detection \nand navigation. As technology continues to evolve, machine learning is becoming an essential part of everyday life and modern innovation.\n'),
#  Document(metadata={'source': '../data/text_files/Introduction_to_Python.txt'}, page_content='Introduction to Python\n\nPython is a high-level, interpreted programming language known for its simple syntax and readability. It was created by \nGuido van Rossum and first released in 1991. Python is widely used in software development, web applications, automation, \nand scientific computing because it allows programmers to write clean and efficient code.\n\nOne of Python’s greatest strengths is its versatility. Developers use it for building websites, analyzing data, creating \nartificial intelligence systems, and automating repetitive tasks. Python supports multiple programming styles, including \nprocedural, object-oriented, and functional programming, making it suitable for both beginners and experienced programmers.\n\nPython also has a large global community and a rich collection of libraries and frameworks. Tools such as Django for \nweb development and TensorFlow for machine learning help developers create powerful applications quickly. Because of its ease \nof learning and broad applications, Python remains one of the most popular programming languages in the world.\n\nKey Features of Python\n - Simple and easy-to-read syntax\n - Interpreted language with fast development cycle\n - Cross-platform compatibility\n - Large standard library and third-party modules\n - Supports object-oriented programming\n - Strong community support\n - Widely used in AI, data science, and web development\n - Open-source and free to use\n\nOverall\n\nPython is a powerful and flexible programming language that is suitable for beginners and professionals alike. Its readability, \nextensive libraries, and wide range of applications make it an excellent choice for modern software development. From \nweb development to artificial intelligence, Python continues to play a major role in the technology industry.\n'),
#  Document(metadata={'source': '../data/text_files/RAG_Basics.txt'}, page_content='RAG Basics\n\nRetrieval-Augmented Generation (RAG) is an advanced AI technique that combines information retrieval with \ntext generation. It enhances the capabilities of large language models by allowing them to access external \nknowledge sources before generating responses. Instead of relying only on pre-trained data, RAG systems search \ndatabases, documents, or websites to retrieve relevant information and produce more accurate and up-to-date answers.\n\nRAG works in two main stages: retrieval and generation. In the retrieval stage, the system searches for relevant \ndata from a knowledge base using similarity search or embeddings. In the generation stage, the retrieved information is \npassed to a language model, which generates a meaningful and context-aware response. Technologies such as LangChain and vector \ndatabases like Pinecone are commonly used to build RAG-based applications.\n\nTypes of RAG Systems\n - Naive RAG\n - Advanced RAG\n - Modular RAG\n - Hybrid RAG\n - Graph-based RAG\n\nApplications of RAG\n\nRAG is widely used in modern AI applications where accurate and updated information is important. It is commonly \napplied in chatbots, virtual assistants, customer support systems, and enterprise search tools. In healthcare and finance, \nRAG helps provide reliable answers from large document collections, while in education it supports intelligent tutoring systems. \nBy combining retrieval and generation, RAG improves response quality, reduces hallucinations, and enables AI systems to deliver more \ntrustworthy information.\n')]

# %%
# Load all pdf files in directory
pdf_dir_loader = DirectoryLoader(
    "../data/pdf_files",
    glob = "**/*.pdf", # Patern to match all files
    loader_cls = PyMuPDFLoader, # Loader class to use
    show_progress = False
)

pdf_docs = pdf_dir_loader.load()
pdf_docs
# Out:
# [Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T12:55:56+02:00', 'source': '../data/pdf_files/MER 2025 - When Affective Computing Meets Large Language Models.pdf', 'file_path': '../data/pdf_files/MER 2025 - When Affective Computing Meets Large Language Models.pdf', 'total_pages': 4, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T12:55:56+02:00', 'trapped': '', 'modDate': "D:20260509125556+02'00'", 'creationDate': "D:20260509125556+02'00'", 'page': 0}, page_content='Title: MER 2025: When Affective Computing Meets Large Language Models \nPublication Date: 2025 \nResearch Field: Affective Computing, Multimodal Emotion Recognition, Human-\nComputer Interaction \nKeywords: Multimodal Emotion Recognition (MER), LLMs, Semi-supervised Learning, Fine-\ngrained Emotion Recognition, Emotion Description, Personality Recognition \nPaper Type: Benchmark / Challenge Paper \nShort Summary \nThis paper introduces MER2025, the third edition of a benchmark challenge focused on \nmultimodal emotion recognition (MER). The central theme is the integration of large \nlanguage models (LLMs) into affective computing to move beyond traditional categorical \nemotion classification toward fine-grained, descriptive, and interpretable emotion \nunderstanding. The challenge is organized into four tracks addressing semi-supervised \nlearning, fine-grained emotion prediction, descriptive emotion reasoning, and emotion-\ninformed personality recognition. The paper presents datasets, baseline models, \nevaluation metrics, and experimental results for each track. \nProblem & Motivation \nTraditional emotion recognition systems rely heavily on: \n• \nPredefined emotion categories (e.g., happy, sad) \n• \nLimited interpretability \n• \nInsufficient use of multimodal cues \nHowever, human emotions are: \n• \nComplex and multi-modal (facial, vocal, textual, physiological) \n• \nOften ambiguous and context-dependent \n• \nBetter expressed through natural language descriptions rather than discrete \nlabels \nThe motivation of the paper is to: \n• \nTransition from categorical to generative emotion understanding \n• \nLeverage LLMs’ open-vocabulary capabilities \n• \nImprove accuracy, flexibility, and interpretability in emotion recognition systems \nSolution Approach \nThe paper proposes a multi-track benchmark framework (MER2025) with four \ncomplementary tasks: \n1. MER-SEMI: Semi-supervised categorical emotion recognition \n2. MER-FG: Fine-grained, open-vocabulary emotion prediction using LLMs'),
#  Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T12:55:56+02:00', 'source': '../data/pdf_files/MER 2025 - When Affective Computing Meets Large Language Models.pdf', 'file_path': '../data/pdf_files/MER 2025 - When Affective Computing Meets Large Language Models.pdf', 'total_pages': 4, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T12:55:56+02:00', 'trapped': '', 'modDate': "D:20260509125556+02'00'", 'creationDate': "D:20260509125556+02'00'", 'page': 1}, page_content='3. MER-DES: Emotion understanding through multimodal natural language \ndescriptions \n4. MER-PR: Personality prediction enhanced by emotion recognition \nThis structure allows researchers to: \n• \nExplore different paradigms of emotion modeling \n• \nCompare models across multiple levels of abstraction \n• \nInvestigate the role of LLMs in multimodal reasoning \nCore Contributions and Novelty \n• \nIntroduction of a comprehensive benchmark integrating LLMs into MER \n• \nShift from fixed-label classification to open-vocabulary and generative modeling \n• \nProposal of multimodal descriptive emotion reasoning (MER-DES) for \ninterpretability \n• \nExploration of emotion–personality interaction (MER-PR) \n• \nLarge-scale datasets combining labeled and unlabeled multimodal data \n• \nStandardized evaluation protocols across multiple paradigms \nThe novelty lies in combining: \n• \nLLMs + multimodal perception \n• \nEmotion recognition + natural language generation \n• \nEmotion + personality modeling \nData/Database & Task Setup \nThe datasets vary across tracks: \nMER-SEMI \n• \nData Type: Video, Audio, Text (multimodal) \n• \nSources: Conversational datasets + 19 Chinese TV series \n• \nSize: \no 7,369 labeled samples \no 124,802 unlabeled samples \no 2,026 test samples \n• \nTask: Classify into 6 emotion categories \nMER-FG \n• \nData Type: Multimodal + open-vocabulary labels \n• \nDatasets: OV-MERD, MER-Caption+ \n• \nTask: Predict multiple, unrestricted emotion labels \nMER-DES \n• \nData Type: Multimodal + textual descriptions \n• \nTask: Generate interpretable emotion descriptions'),
#  Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T12:55:56+02:00', 'source': '../data/pdf_files/MER 2025 - When Affective Computing Meets Large Language Models.pdf', 'file_path': '../data/pdf_files/MER 2025 - When Affective Computing Meets Large Language Models.pdf', 'total_pages': 4, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T12:55:56+02:00', 'trapped': '', 'modDate': "D:20260509125556+02'00'", 'creationDate': "D:20260509125556+02'00'", 'page': 2}, page_content='MER-PR \n• \nData Type: Multimodal + personality annotations \n• \nDataset: MDPE \n• \nTask: Predict Big Five personality traits \nMethodology \nThe methodology differs per track: \n• \nMER-SEMI: \no Semi-supervised learning using unlabeled data \no Feature extraction + attention-based multimodal fusion \n• \nMER-FG: \no LLM-driven emotion generation \no Multi-stage evaluation using label normalization and grouping (emotion \nwheels) \n• \nMER-DES: \no Generation of natural language explanations using multimodal cues \no Human-based evaluation for interpretability \n• \nMER-PR: \no Regression-based personality prediction \no Multimodal feature fusion via concatenation and neural layers \nModel Details \nDifferent models are used across modalities: \nUnimodal Models \n• \nVisual: ResNet, DINOv2, CLIP \n• \nAudio: wav2vec 2.0, HuBERT, WavLM \n• \nText: RoBERTa, MacBERT, BLOOM \nMultimodal & LLM Models \n• \nMLLMs: SALMONN, Chat-UniVi, Video-LLaVA \n• \nLLMs: Qwen2.5 \n• \nSpecialized Model: AffectGPT (emotion-focused multimodal LLM) \nUse Cases \n• \nFeature extraction (visual/audio/text) \n• \nMultimodal fusion \n• \nEmotion generation (LLMs) \n• \nDescription generation \n• \nPersonality regression \nEvaluation & Metrics'),
#  Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T12:55:56+02:00', 'source': '../data/pdf_files/MER 2025 - When Affective Computing Meets Large Language Models.pdf', 'file_path': '../data/pdf_files/MER 2025 - When Affective Computing Meets Large Language Models.pdf', 'total_pages': 4, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T12:55:56+02:00', 'trapped': '', 'modDate': "D:20260509125556+02'00'", 'creationDate': "D:20260509125556+02'00'", 'page': 3}, page_content='MER-SEMI \n• \nAccuracy \n• \nWeighted Average F1-score (WAF) (primary due to class imbalance) \nMER-FG \n• \nPrecision, Recall, F1-score with multi-level grouping strategies \n• \nFinal metrics: S1 (coarse) and S2 (fine-grained) scores \nMER-DES \n• \nHuman evaluation based on: \no Presence of multimodal evidence \no Logical consistency of descriptions \nMER-PR \n• \nRoot Mean Square Error (RMSE) for personality prediction \nThe evaluation design reflects: \n• \nIncreasing complexity from classification → generation → reasoning \nPractical Impact & Future Works \nPractical Impact \n• \nEnables emotion-aware AI systems in: \no Healthcare \no Education \no Human-computer interaction \n• \nImproves interpretability of AI decisions \n• \nBridges LLMs with affective computing \nFuture Directions \n• \nBetter integration of multimodal reasoning in LLMs \n• \nMore scalable annotation strategies for subjective tasks \n• \nAdvanced fusion techniques tailored to tasks \n• \nDeeper exploration of emotion–personality relationships \n• \nImproved evaluation metrics for generative emotion understanding \nOverall Assessment \nThis paper provides a well-structured benchmark and forward-looking framework for \nthe next generation of emotion recognition systems. Its main strength lies in redefining \nemotion understanding as a multimodal, generative, and interpretable task, leveraging \nthe capabilities of LLMs.'),
#  Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T12:53:22+02:00', 'source': '../data/pdf_files/AffectGPT - A New Dataset, Model, and Benchmark for Emotion Understanding with Multimodal Large Language Models.pdf', 'file_path': '../data/pdf_files/AffectGPT - A New Dataset, Model, and Benchmark for Emotion Understanding with Multimodal Large Language Models.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T12:53:22+02:00', 'trapped': '', 'modDate': "D:20260509125322+02'00'", 'creationDate': "D:20260509125322+02'00'", 'page': 0}, page_content='Title: AffectGPT: A New Dataset, Model, and Benchmark for Emotion Understanding with \nMultimodal Large Language Models \nPublication Date: 2025 \nResearch Field: Multimodal Emotion Recognition (MER), Multimodal Large Language \nModels (MLLMs), Affective Computing \nKeywords: Emotion Understanding, Multimodal Learning, Large Language Models, Dataset \nConstruction, Benchmarking, Emotion Recognition \nPaper Type: Benchmark + Model + Dataset (combined research contribution paper) \nShort Summary \nThis paper introduces a comprehensive framework for advancing emotion understanding \nusing Multimodal Large Language Models (MLLMs). It proposes: \n1. A large-scale descriptive dataset (MER-Caption) with over 115K samples and \n~2,900 emotion categories. \n2. A novel multimodal model (AffectGPT) with enhanced fusion via pre-fusion \noperations. \n3. A unified evaluation benchmark (MER-UniBench) tailored to free-form emotional \nlanguage outputs. \nThe results demonstrate significant improvements (over 9%) compared to existing MLLMs \nacross multiple emotion recognition tasks. \nProblem & Motivation \nTraditional emotion recognition systems rely on discrete classification frameworks (e.g., \nEkman’s six emotions), which fail to capture: \n• \nThe diversity of emotional expressions \n• \nThe coexistence of multiple emotions \n• \nThe contextual and cultural nuances of human affect \nMoreover, existing limitations include: \n• \nLack of large-scale descriptive emotion datasets \n• \nInsufficient multimodal fusion strategies in current MLLMs \n• \nAbsence of evaluation benchmarks for free-form emotion descriptions \nThe motivation is to shift from closed-set classification to open-ended, natural language \nemotion understanding enabled by MLLMs. \nSolution Approach \nThe paper addresses the problem through three key components: \n1. Dataset: Construct MER-Caption using a model-led, human-assisted annotation \nstrategy.'),
#  Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T12:53:22+02:00', 'source': '../data/pdf_files/AffectGPT - A New Dataset, Model, and Benchmark for Emotion Understanding with Multimodal Large Language Models.pdf', 'file_path': '../data/pdf_files/AffectGPT - A New Dataset, Model, and Benchmark for Emotion Understanding with Multimodal Large Language Models.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T12:53:22+02:00', 'trapped': '', 'modDate': "D:20260509125322+02'00'", 'creationDate': "D:20260509125322+02'00'", 'page': 1}, page_content='2. Model: Develop AffectGPT with pre-fusion multimodal integration to better \ncapture cross-modal interactions. \n3. Benchmark: Create MER-UniBench with custom evaluation metrics for free-form \noutputs. \nThis integrated approach targets both data limitations and model architecture \nweaknesses in existing systems. \nCore Contributions and Novelty \n• \nIntroduction of the largest multimodal descriptive emotion dataset (115K \nsamples, 2K+ emotion categories). \n• \nProposal of a model-led human-assisted annotation paradigm, balancing \nscalability and quality. \n• \nDevelopment of AffectGPT, which explicitly enhances multimodal fusion via pre-\nfusion operations. \n• \nCreation of MER-UniBench, a unified benchmark supporting: \no Fine-grained emotion recognition \no Basic emotion classification \no Sentiment analysis \n• \nDesign of new evaluation metrics for free-form emotion descriptions. \nThese contributions collectively shift MER toward generative, open-vocabulary emotion \nunderstanding. \nData/Database & Task Setup \nData Types \n• \nVideo/Visual \n• \nAudio \n• \nText (subtitles/dialogue) \nDataset: MER-Caption \n• \n115,595 samples (coarse labels) \n• \n31,327 samples (fine labels in MER-Caption+) \n• \n~2,932 emotion categories \n• \nMultimodal inputs: Audio + Video + Text \nTask Setup (MER-UniBench) \n1. Fine-grained Emotion Recognition \no Open vocabulary, multiple labels per sample \n2. Basic Emotion Recognition \no Single-label classification (e.g., happy, sad) \n3. Sentiment Analysis'),
#  Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T12:53:22+02:00', 'source': '../data/pdf_files/AffectGPT - A New Dataset, Model, and Benchmark for Emotion Understanding with Multimodal Large Language Models.pdf', 'file_path': '../data/pdf_files/AffectGPT - A New Dataset, Model, and Benchmark for Emotion Understanding with Multimodal Large Language Models.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T12:53:22+02:00', 'trapped': '', 'modDate': "D:20260509125322+02'00'", 'creationDate': "D:20260509125322+02'00'", 'page': 2}, page_content='o Binary/ternary polarity (positive/negative/neutral) \nDatasets used include OV-MERD+, MER2023/2024, IEMOCAP, MELD, CMU-MOSI, MOSEI, \nand CH-SIMS. \nMethodology \nDataset Construction \n• \nModel-led human-assisted annotation \no Audio cues: SALMONN \no Visual cues: Chat-UniVi \no Fusion: GPT-3.5 \n• \nTwo-stage filtering: \no Low-level: remove mismatched audio-video & abnormal samples \no High-level: model-based crowdsourcing with majority voting \nModel Design \n• \nStandard MLLM pipeline: encoders + projector + LLM \n• \nProposed improvement: pre-fusion before LLM processing \nPre-fusion Mechanisms \n1. Q-Former-based fusion \no Uses learnable query tokens for cross-modal interaction \n2. Attention-based fusion \no Compresses features and applies attention weighting \nTraining Objective \n• \nAutoregressive generation: \n[P(R|X_v, X_a, X_t, Q)] \nModel Details \nAffectGPT \n• \nInputs: Audio, Video, Text \n• \nComponents: \no Visual encoder (e.g., CLIP ViT-L) \no Audio encoder (e.g., HuBERT-L) \no Pre-fusion module (Q-Former or Attention) \no LLM (Qwen2.5 with LoRA fine-tuning) \nSupporting Models Used \n• \nSALMONN (audio understanding) \n• \nChat-UniVi (video understanding) \n• \nGPT-3.5 (annotation fusion) \nKey Innovation'),
#  Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T12:53:22+02:00', 'source': '../data/pdf_files/AffectGPT - A New Dataset, Model, and Benchmark for Emotion Understanding with Multimodal Large Language Models.pdf', 'file_path': '../data/pdf_files/AffectGPT - A New Dataset, Model, and Benchmark for Emotion Understanding with Multimodal Large Language Models.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T12:53:22+02:00', 'trapped': '', 'modDate': "D:20260509125322+02'00'", 'creationDate': "D:20260509125322+02'00'", 'page': 3}, page_content='• \nMoves cross-modal interaction outside the LLM, improving multimodal reasoning \nefficiency. \nEvaluation & Metrics \nFine-grained Emotion Recognition \n• \nSet-based metrics: \no Precision (Ps) \no Recall (Rs) \no F-score (Fs) (primary metric) \nBasic Emotion Recognition \n• \nHit Rate (HIT) \no Measures if ground-truth emotion appears in predicted set \nSentiment Analysis \n• \nWeighted Average F-score (WAF) (primary) \n• \nAccuracy (ACC) \nBenchmark Characteristics \n• \nHandles free-form natural language outputs \n• \nUses synonym normalization and emotion grouping \nPractical Impact & Future Works \nPractical Impact \n• \nEnables more human-like emotion understanding in AI systems \n• \nApplicable to: \no Human-computer interaction \no Mental health and counseling systems \no Education and affect-aware systems \no Social robotics \n• \nProvides a scalable dataset and benchmark for future research \nFuture Work \n• \nImprove annotation quality via advanced filtering techniques \n• \nExtend to multi-person emotion recognition scenarios \n• \nDevelop better metrics for evaluating incorrect or extra predicted emotions \n• \nAddress modality conflicts and reasoning complexity \nOverall Assessment \nThis paper makes a substantial contribution by jointly addressing: \n• \nData scarcity \n• \nModel limitations \n• \nEvaluation challenges'),
#  Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T12:53:22+02:00', 'source': '../data/pdf_files/AffectGPT - A New Dataset, Model, and Benchmark for Emotion Understanding with Multimodal Large Language Models.pdf', 'file_path': '../data/pdf_files/AffectGPT - A New Dataset, Model, and Benchmark for Emotion Understanding with Multimodal Large Language Models.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T12:53:22+02:00', 'trapped': '', 'modDate': "D:20260509125322+02'00'", 'creationDate': "D:20260509125322+02'00'", 'page': 4}, page_content='Its integrated approach (dataset + model + benchmark) positions it as a foundational work \nfor next-generation emotion-aware MLLMs.'),
#  Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T12:57:54+02:00', 'source': '../data/pdf_files/Multimodal Large Language Models Meet Multimodal Emotion Recognition and Reasoning - A Survey.pdf', 'file_path': '../data/pdf_files/Multimodal Large Language Models Meet Multimodal Emotion Recognition and Reasoning - A Survey.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T12:57:54+02:00', 'trapped': '', 'modDate': "D:20260509125754+02'00'", 'creationDate': "D:20260509125754+02'00'", 'page': 0}, page_content='Title: Multimodal Large Language Models Meet Multimodal Emotion Recognition and \nReasoning: A Survey \nPublication Date: September 2025 \nResearch Field: Artificial Intelligence, NLP, Multimodal Learning, Affective Computing \nKeywords: Multimodal Emotion Recognition, Multimodal Large Language Models (MLLMs), \nDeep Learning, Emotion Reasoning, Cross-modal Fusion \nPaper Type: Survey / Review Paper \nShort Summary \nThis paper presents the first comprehensive survey of Large Language Models (LLMs) and \nMultimodal Large Language Models (MLLMs) applied to multimodal emotion recognition \nand reasoning. It systematically reviews model architectures, datasets, and evaluation \nbenchmarks, and proposes a taxonomy based on parameter-freezing and parameter-\ntuning paradigms. The survey highlights the transition from traditional multimodal learning \napproaches to MLLM-driven reasoning frameworks, emphasizing improvements in cross-\nmodal understanding, zero-/few-shot learning, and explainability. It also identifies key \nchallenges such as fine-grained alignment and temporal reasoning, and outlines future \nresearch directions. \nProblem & Motivation \nThe core problem addressed is the lack of a unified and systematic understanding of \nhow LLMs and MLLMs contribute to multimodal emotion recognition and reasoning. \n• \nTraditional approaches rely heavily on supervised learning with labeled \nmultimodal data, limiting scalability. \n• \nLLMs are powerful in language reasoning but cannot process non-text modalities \ndirectly. \n• \nExisting multimodal methods struggle with cross-modal interaction and reasoning \ncomplexity. \nThe motivation is to: \n• \nBridge the gap between language reasoning and multimodal perception. \n• \nProvide a comprehensive overview of emerging MLLM-based approaches. \n• \nIdentify whether MLLMs can replace or complement traditional methods and \ndefine future directions. \nSolution Approach \nThe paper addresses the problem through a systematic survey methodology, including: \n• \nReviewing LLM-based and MLLM-based approaches for emotion recognition. \n• \nProposing a unified taxonomy: \no Parameter-frozen methods (zero-/few-shot learning)'),
#  Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T12:57:54+02:00', 'source': '../data/pdf_files/Multimodal Large Language Models Meet Multimodal Emotion Recognition and Reasoning - A Survey.pdf', 'file_path': '../data/pdf_files/Multimodal Large Language Models Meet Multimodal Emotion Recognition and Reasoning - A Survey.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T12:57:54+02:00', 'trapped': '', 'modDate': "D:20260509125754+02'00'", 'creationDate': "D:20260509125754+02'00'", 'page': 1}, page_content='o Parameter-tuning methods (full and efficient tuning) \n• \nAnalyzing model architectures, datasets, and evaluation strategies. \n• \nProviding a unified framework explaining how MLLMs perform multimodal \nreasoning via cross-modal fusion. \nCore Contributions and Novelty \n1. First comprehensive survey combining LLMs, MLLMs, and multimodal emotion \nreasoning. \n2. New taxonomy distinguishing: \no Parameter-frozen vs. parameter-tuning paradigms \n3. Unified framework explaining multimodal reasoning pipelines. \n4. Extensive benchmark and dataset review, covering both recognition and \nreasoning tasks. \n5. Identification of research challenges (e.g., alignment, temporal modeling). \n6. Practical insights and future directions for advancing MLLM-based emotion \nsystems. \nData/Database & Task Setup \nData Types \n• \nVideo / Visual: facial expressions, gestures \n• \nAudio: speech signals, prosody (pitch, tone, pauses) \n• \nText: transcripts, dialogue \n• \nPhysiological signals (in some datasets) \nTask Setup \n• \nMultimodal Emotion Recognition: Predict emotion labels from multimodal inputs \n• \nMultimodal Emotion Reasoning: Predict emotion + generate explanations \n(rationales) \nFormally: \n• \nRecognition: mapping ( X \\rightarrow Y ) \n• \nReasoning: mapping ( X \\rightarrow (Y, R) ) (label + reasoning) \nMethodology \nThe methodology consists of analyzing different modeling paradigms: \n1. Traditional Multimodal Methods \n• \nFeature-level and decision-level fusion \n• \nDeep learning models: \no CNNs (spatial features) \no RNN/LSTM (temporal modeling) \no Transformers (attention-based fusion)'),
#  Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T12:57:54+02:00', 'source': '../data/pdf_files/Multimodal Large Language Models Meet Multimodal Emotion Recognition and Reasoning - A Survey.pdf', 'file_path': '../data/pdf_files/Multimodal Large Language Models Meet Multimodal Emotion Recognition and Reasoning - A Survey.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T12:57:54+02:00', 'trapped': '', 'modDate': "D:20260509125754+02'00'", 'creationDate': "D:20260509125754+02'00'", 'page': 2}, page_content='o GNNs (structured relationships) \n2. LLM-based Methods \n• \nConvert multimodal features into textual representations \n• \nFeed into LLM for reasoning \n• \nLimitation: weak cross-modal interaction \n3. MLLM-based Methods \n• \nUse modality encoders + connector modules (MLP, Q-Former, cross-attention) \n• \nEnable end-to-end multimodal reasoning \n• \nPreserve modality-specific information while enabling fusion \n4. Learning Paradigms \n• \nParameter-frozen: zero-shot, few-shot prompting \n• \nParameter-tuning: \no Full fine-tuning \no Parameter-efficient tuning (LoRA, adapters) \nModel Details \nThe paper discusses multiple representative models: \nLLM-based Models \n• \nGPT family \n• \nChatGLM \n• \nText-based reasoning pipelines \nMLLM-based Models \n• \nGPT-4V / GPT-4o \n• \nGemini series \n• \nLLaVA, Video-LLaMA, MiniGPT \n• \nQwen-VL, Qwen-Audio \n• \nEmotion-specific models: \no Emotion-LLaMA \no AffectGPT \nModel Use Cases \n• \nZero-shot emotion recognition \n• \nFew-shot reasoning tasks \n• \nMultimodal dialogue understanding \n• \nEmotion explanation generation \nEvaluation & Metrics \nThe evaluation spans multiple benchmarks and metrics: \nRecognition Metrics'),
#  Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T12:57:54+02:00', 'source': '../data/pdf_files/Multimodal Large Language Models Meet Multimodal Emotion Recognition and Reasoning - A Survey.pdf', 'file_path': '../data/pdf_files/Multimodal Large Language Models Meet Multimodal Emotion Recognition and Reasoning - A Survey.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T12:57:54+02:00', 'trapped': '', 'modDate': "D:20260509125754+02'00'", 'creationDate': "D:20260509125754+02'00'", 'page': 3}, page_content='• \nAccuracy \n• \nPrecision / Recall \n• \nF1-score \n• \nWeighted Accuracy (WAR), Unweighted Accuracy (UAR) \nReasoning Metrics \n• \nReasoning Score (Rea-S) \n• \nChain-of-Thought Score (CoT-S) \n• \nExplanation quality (BLEU, ROUGE) \nOther Evaluations \n• \nCross-modal robustness \n• \nDistance-based performance (e.g., MOSABench) \n• \nEmotional intelligence benchmarks (e.g., EmoBench) \nExperiments compare: \n• \nZero-shot vs. fine-tuned models \n• \nOpen-source vs. closed-source models \nPractical Impact & Future Works \nPractical Impact \n• \nEnables more accurate and explainable emotion-aware AI systems \n• \nApplications: \no Human-computer interaction \no Mental health analysis \no Conversational agents \no Social media analysis \nFuture Research Directions \n1. Fine-grained multimodal alignment (micro-expressions, prosody) \n2. Temporal reasoning across modalities \n3. Efficient and scalable architectures (LoRA, MoE) \n4. Improved multimodal datasets with reasoning annotations \n5. Integration of causal reasoning and commonsense knowledge \nThe paper emphasizes that future systems must combine: \n• \nStrong perception (multimodal understanding) \n• \nDeep reasoning (LLM capabilities) \nto achieve robust emotion intelligence. \nOverall Assessment \nThis survey is highly comprehensive and timely, offering: \n• \nA clear taxonomy'),
#  Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T12:57:54+02:00', 'source': '../data/pdf_files/Multimodal Large Language Models Meet Multimodal Emotion Recognition and Reasoning - A Survey.pdf', 'file_path': '../data/pdf_files/Multimodal Large Language Models Meet Multimodal Emotion Recognition and Reasoning - A Survey.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T12:57:54+02:00', 'trapped': '', 'modDate': "D:20260509125754+02'00'", 'creationDate': "D:20260509125754+02'00'", 'page': 4}, page_content='• \nStrong conceptual unification \n• \nExtensive empirical insights \nIts main strength lies in bridging multimodal perception and language reasoning, though \nit highlights that fine-grained alignment and temporal modeling remain open \nchallenges.'),
#  Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T13:09:16+02:00', 'source': '../data/pdf_files/OV-MER - Towards Open-Vocabulary Multimodal Emotion Recognition.pdf', 'file_path': '../data/pdf_files/OV-MER - Towards Open-Vocabulary Multimodal Emotion Recognition.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T13:09:16+02:00', 'trapped': '', 'modDate': "D:20260509130916+02'00'", 'creationDate': "D:20260509130916+02'00'", 'page': 0}, page_content='Title: OV-MER: Towards Open-Vocabulary Multimodal Emotion Recognition \nPublication Date: 2025 \nResearch Field: Multimodal Emotion Recognition, Affective Computing, Multimodal Large \nLanguage Models, Human–Computer Interaction \nKeywords: Open-vocabulary emotion recognition, multimodal emotion recognition, \naffective computing, MLLMs, human-LLM annotation, emotion datasets, zero-shot \nbenchmark \nPaper Type: New task/paradigm paper, dataset paper, benchmark paper, and preliminary \nmethodological study. \nShort Summary \nThis paper introduces Open-Vocabulary Multimodal Emotion Recognition (OV-MER), a \nnew paradigm that moves beyond traditional fixed-label emotion recognition. Existing MER \nsystems usually classify samples into a small predefined set of emotions such as \nhappiness, anger, sadness, or surprise. The authors argue that this restricted setting \ncannot capture the complexity, subtlety, and compound nature of real human emotions. \nTo address this limitation, the paper proposes OV-MER, where models can predict any \nnumber of emotion labels from an unrestricted label space. The authors construct a \nnew dataset, OV-MERD, using a human-LLM collaborative annotation pipeline. They also \ndesign new set-based evaluation metrics and benchmark several multimodal large \nlanguage models. The results show that current MLLMs can partially perform OV-MER but \nstill struggle with nuanced multimodal emotional understanding. \nProblem & Motivation \nThe core problem addressed by the paper is the limited expressiveness of conventional \nmultimodal emotion recognition. Traditional MER tasks generally rely on either \ndimensional models, such as valence-arousal-dominance, or discrete taxonomies, such \nas Ekman’s basic emotions. While useful, these approaches compress rich emotional \nstates into a small set of categories. \nThe paper argues that real emotional experiences are often subtle, compound, and \ncontext-dependent. For example, a person labeled simply as “happy” may actually express \nhumor, mockery, irony, or sarcasm. This motivates the shift from one-hot MER and multi-\nlabel MER with fixed categories to open-vocabulary MER, where models can produce \nricher and more human-like emotion descriptions. The visual comparison on page 2 clearly \nillustrates this difference: a traditional one-hot label gives only “happy,” while OV-MER \nidentifies more nuanced labels such as “humor,” “mockery,” and “irony.” \nSolution Approach'),
#  Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T13:09:16+02:00', 'source': '../data/pdf_files/OV-MER - Towards Open-Vocabulary Multimodal Emotion Recognition.pdf', 'file_path': '../data/pdf_files/OV-MER - Towards Open-Vocabulary Multimodal Emotion Recognition.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T13:09:16+02:00', 'trapped': '', 'modDate': "D:20260509130916+02'00'", 'creationDate': "D:20260509130916+02'00'", 'page': 1}, page_content='The authors solve the problem by proposing a complete foundational framework for OV-\nMER, including: \n1. A new task definition: OV-MER allows prediction of arbitrary emotion categories \nand arbitrary numbers of labels. \n2. A new dataset: OV-MERD extends MER2023 with open-vocabulary emotion \nannotations. \n3. A human-LLM annotation pipeline: LLMs and MLLMs generate multimodal clues, \nwhile human annotators verify and refine them. \n4. New evaluation metrics: Because labels are open-ended, the paper groups \nsemantically similar emotions and evaluates predictions using set-based precision, \nrecall, and F-score. \n5. Benchmark experiments: The authors evaluate existing MLLMs under zero-shot \nsettings and compare modality-specific variants. \nThis approach is not only a dataset contribution but also an attempt to redefine how \nemotion recognition should be evaluated when the label space is no longer fixed. \nCore Contributions and Novelty \nThe main novelty of the paper lies in introducing open vocabulary into multimodal \nemotion recognition. Its contributions are: \nFirst, the paper defines OV-MER as a new MER paradigm. Unlike one-hot MER, which \npredicts one label, or multi-label MER, which predicts multiple labels from a limited set, \nOV-MER predicts any number of emotions from an unrestricted vocabulary. \nSecond, the paper constructs OV-MERD, a dataset with 236 emotion categories, where \nmost samples contain 2–4 labels and some contain up to 9 labels. This is substantially \nricher than traditional datasets such as MER2023 and MER2024, which use only 6 discrete \nemotion categories and one label per sample. \nThird, the paper proposes a human-LLM collaborative annotation strategy. GPT-4V is \nused for visual pre-annotation, SALMONN is used for audio pre-annotation, GPT-3.5 \nmerges textual, visual, and acoustic clues, and human annotators perform multi-round \nchecking. \nFourth, the authors introduce OV-MER-specific evaluation metrics. Since “happy” and \n“joyful” may be semantically close but lexically different, direct label matching is \ninsufficient. The paper therefore introduces grouping-based set metrics. \nFifth, the paper provides a benchmark for MLLMs. It evaluates several audio, video, and \nmultimodal LLMs, showing that current models remain limited in capturing fine-grained \nemotional states. \nData/Database & Task Setup'),
#  Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T13:09:16+02:00', 'source': '../data/pdf_files/OV-MER - Towards Open-Vocabulary Multimodal Emotion Recognition.pdf', 'file_path': '../data/pdf_files/OV-MER - Towards Open-Vocabulary Multimodal Emotion Recognition.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T13:09:16+02:00', 'trapped': '', 'modDate': "D:20260509130916+02'00'", 'creationDate': "D:20260509130916+02'00'", 'page': 2}, page_content='The paper introduces OV-MERD, an open-vocabulary multimodal emotion recognition \ndataset derived from MER2023. MER2023 consists of movie and TV-series video clips, \nmostly single-person clips with relatively complete speech content. The authors randomly \nselect a subset from MER2023 and perform additional annotation for OV-MER. \nModalities used: \n• \nText: subtitles or speech transcripts. \n• \nAudio: speech tone, intonation, stuttering, emphasis, and other paralinguistic cues. \n• \nVideo/Visual: facial expressions, body language, gaze direction, gestures, and \ntemporal changes. \nTask setup: Given a multimodal video sample containing text, audio, and visual \ninformation, the model must predict a set of open-vocabulary emotion labels. Unlike \ntraditional MER, the output is not restricted to a fixed taxonomy. A sample may have labels \nsuch as nervous, mockery, dissatisfied, pressure, threat, uneasy, or grateful. \nThe dataset comparison table shows that OV-MERD uses audio, video, and text, has \ndiscrete emotion annotations, contains 236 categories, and allows arbitrary label numbers \nper sample. \nMethodology \nThe methodology consists of two major stages: dataset construction and benchmark \nevaluation. \nIn the dataset construction stage, the authors first generate multimodal emotion-related \nclues. For video, GPT-4V is used as a video-language model by sampling three frames from \neach video. For audio, SALMONN is used as an audio-language model. Human annotators \nthen manually check these pre-annotations to remove hallucinated or repeated content \nand add missing details. The checked acoustic and visual clues are merged with text using \nGPT-3.5 to produce CLUE-Multi, a rich emotion-related description. \nNext, GPT-3.5 extracts open-vocabulary emotion labels from CLUE-Multi. Since the dataset \ninvolves both Chinese and English descriptions, the authors analyze language effects by \nextracting labels from both languages, translating them, and comparing their similarity. To \nreduce language bias, they merge bilingual label outputs and conduct manual checks. \nThese checked labels become the ground truth. \nFor evaluation, the authors introduce grouping-based metrics. They group similar emotion \nlabels using either GPT-based grouping or Emotion Wheel-based grouping. Then they \ncompute set-based Precision, Recall, and F-score, where the prediction is evaluated as a \nset of emotion concepts rather than an ordered list. \nModel Details \nThe paper evaluates several model types and variants.'),
#  Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T13:09:16+02:00', 'source': '../data/pdf_files/OV-MER - Towards Open-Vocabulary Multimodal Emotion Recognition.pdf', 'file_path': '../data/pdf_files/OV-MER - Towards Open-Vocabulary Multimodal Emotion Recognition.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T13:09:16+02:00', 'trapped': '', 'modDate': "D:20260509130916+02'00'", 'creationDate': "D:20260509130916+02'00'", 'page': 3}, page_content='GPT-4V: Used as a video-language model for visual pre-annotation. Because GPT-4V \nprocesses images rather than full videos in this pipeline, the authors uniformly sample \nthree frames per video. \nSALMONN: Used as an audio-language model for acoustic pre-annotation. It helps identify \naudio-related emotional cues, although the paper notes that audio LLMs often struggle \nwith paralinguistic emotion features. \nGPT-3.5: Used for several core functions: merging text, audio, and visual clues into CLUE-\nMulti; extracting open-vocabulary emotion labels; translating between Chinese and \nEnglish; and grouping similar emotion labels. \nCLUE-Multi: A multimodal upper-bound description generated from checked visual clues, \nchecked acoustic clues, and text. It represents the strongest manually supported \nmultimodal condition. \nCLUE-Audio: Uses checked acoustic clues plus text to infer emotion labels. \nCLUE-Video: Uses checked visual clues only. \nCLUE-Text: Uses only textual content. \nCLUE-MLLM: Uses outputs from MLLMs without manual checking. This setting better \nreflects fully automatic model performance. \nBenchmarked MLLMs: The paper evaluates models including Qwen-Audio, OneLLM, \nOtter, Video-LLaMA, VideoChat, SECap, PandaGPT, Video-LLaVA, SALMONN, VideoChat2, \nVideo-ChatGPT, LLaMA-VID, mPLUG-Owl, Chat-UniVi, and GPT-4V. The models are \nassessed in zero-shot settings for their ability to generate emotion-related descriptions and \nsupport OV label prediction. \nEvaluation & Metrics \nThe paper argues that standard classification metrics are insufficient because OV-MER has \nno fixed label space. A model may predict “joyful” while the ground truth says “happy,” and \ndirect string matching would wrongly treat them as unrelated. Therefore, the paper \nproposes emotion grouping before metric calculation. \nTwo grouping strategies are used: \nGPT-based grouping: GPT-3.5 groups similar emotion labels based on semantic similarity. \nEmotion Wheel-based grouping: The authors use psychological emotion wheels and \nexpand labels with synonyms and word forms to create more reproducible groupings. \nAfter grouping, the paper computes: \nSet-based Precision: Measures how many predicted emotion groups are correct. \nSet-based Recall: Measures how many ground-truth emotion groups are covered. \nSet-based F-score: Harmonic mean of precision and recall; used as the main ranking \nmetric.'),
#  Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T13:09:16+02:00', 'source': '../data/pdf_files/OV-MER - Towards Open-Vocabulary Multimodal Emotion Recognition.pdf', 'file_path': '../data/pdf_files/OV-MER - Towards Open-Vocabulary Multimodal Emotion Recognition.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T13:09:16+02:00', 'trapped': '', 'modDate': "D:20260509130916+02'00'", 'creationDate': "D:20260509130916+02'00'", 'page': 4}, page_content='The main results show that CLUE-Multi achieves the best upper-bound performance, with \nan English F-score of about 80.05 and a Chinese F-score of about 85.16. This confirms the \nvalue of integrating text, audio, and visual cues. Among automatic MLLM-based baselines, \nGPT-4V achieves strong results, but its score remains far below CLUE-Multi, indicating that \ncurrent MLLMs still struggle with subtle multimodal emotion understanding. \nThe paper also conducts user studies. One study shows that 97.5% of annotations judged \nOV-MERD labels as more informative than traditional basic emotion labels. Another study \nfinds that 96% of annotations judge OV-MERD labels as aligned with human perception. \nPractical Impact & Future Works \nThe practical impact of this paper is significant for human-centered AI, especially systems \nthat need to understand nuanced emotional states. OV-MER could improve applications \nsuch as conversational agents, social robots, mental well-being interfaces, tutoring \nsystems, and empathetic dialogue systems by allowing them to detect emotions beyond a \nsmall set of basic labels. \nThe paper also highlights important ethical boundaries. It states that the dataset should be \nused only for academic research and non-sensitive human-computer interaction \nscenarios. The authors explicitly warn against using emotion recognition in sensitive \ndomains such as interrogation, hiring, loan approval, or educational evaluation. \nFor future work, the paper identifies several directions. First, stronger OV-MER models are \nneeded, especially MLLMs fine-tuned with emotion-related instruction data. Second, \nfuture work should better integrate subtitles, audio, and visual information. Third, the \nbenchmark should be expanded to include more MLLMs. Fourth, the authors note the need \nto examine cultural differences, since the original data and annotators are Chinese. Finally, \nthey propose collecting more spontaneous real-life emotional data and studying domain \nadaptation to reduce the gap between acted media data and natural emotional behavior. \nOverall, the paper is a strong foundational contribution. Its main value lies less in \nproposing a final high-performing model and more in redefining the MER problem itself: \nfrom recognizing a few basic emotions to capturing the open-ended, subtle, and \nmultimodal nature of human affect.'),
#  Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T13:12:30+02:00', 'source': '../data/pdf_files/Pioneering Multimodal Emotion Recognition in the Era of Large Models.pdf', 'file_path': '../data/pdf_files/Pioneering Multimodal Emotion Recognition in the Era of Large Models.pdf', 'total_pages': 5, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T13:12:30+02:00', 'trapped': '', 'modDate': "D:20260509131230+02'00'", 'creationDate': "D:20260509131230+02'00'", 'page': 0}, page_content='Title: Pioneering Multimodal Emotion Recognition in the Era of Large Models: From Closed \nSets to Open Vocabularies \nPublication date: 24 December 2025 \nResearch field: Multimodal emotion recognition (MER), affective computing, multimodal \nlarge language models (MLLMs), open-vocabulary emotion understanding \nKeywords: MER, Open Vocabulary, MLLMs, LLMs, Prompt Engineering \nPaper type: Benchmarking and empirical evaluation study \nShort Summary \nThis paper presents a comprehensive benchmark for open-vocabulary multimodal \nemotion recognition, referred to as MER-OV, in the context of modern large language \nmodels and multimodal large language models. Unlike traditional emotion recognition \nsystems that classify emotions into fixed categories such as happiness, anger, or sadness, \nMER-OV aims to generate flexible natural-language emotion labels that better reflect \nsubtle, blended, and context-dependent emotional states. \nThe authors evaluate 19 mainstream models, including general-purpose LLMs, Video-\nLLMs, Audio-LLMs, and reasoning-enhanced LLMs, on the OV-MERD dataset. The study \ncompares multiple architectures, modality fusion strategies, video-processing techniques, \nand prompting methods. The key finding is that a two-stage emotional clue-based \nframework using trimodal fusion of text, video, and audio performs best. The study also \nfinds that video is the most important modality, while audio provides useful but secondary \ninformation. \nProblem & Motivation \nThe paper addresses the limitations of conventional emotion recognition approaches, \nwhich usually rely on closed emotion sets or fixed affective dimensions such as valence, \narousal, and dominance. These approaches simplify human emotion into predefined \ncategories and therefore struggle to capture nuanced emotional expressions, cultural \nvariation, mixed emotions, and context-dependent affective states. \nThe motivation behind the work is that recent multimodal large language models have \nstrong capabilities in language generation, cross-modal reasoning, and contextual \nunderstanding. These abilities make them promising tools for open-vocabulary emotion \nrecognition. However, before this paper, the authors argue that there was no systematic \nlarge-scale evaluation of how well MLLMs perform on MER-OV. The paper therefore aims to \nestablish an empirical benchmark and provide practical guidance for future research in \nopen-vocabulary affective computing. \nSolution Approach'),
# ...
#  Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T13:05:42+02:00', 'source': '../data/pdf_files/Multimodal Sensing-Enabled Large Language Models for Automated Emotional Regulation.pdf', 'file_path': '../data/pdf_files/Multimodal Sensing-Enabled Large Language Models for Automated Emotional Regulation.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T13:05:42+02:00', 'trapped': '', 'modDate': "D:20260509130542+02'00'", 'creationDate': "D:20260509130542+02'00'", 'page': 1}, page_content='settings. The authors therefore argue that multimodal sensing can improve emotional state \nperception, while LLMs can improve the quality, fluency, and contextual appropriateness of \ntherapeutic interaction. \nSolution Approach \nThe paper does not propose a new experimentally tested model; instead, it synthesizes \nexisting technologies and proposes a conceptual framework for multimodal sensing-\nenabled LLM-based AER. \nThe solution approach is based on integrating four main capabilities: \n1. Multimodal sensing to collect emotional signals from visual, auditory, \nphysiological, neurocognitive, behavioral, and contextual sources. \n2. Multimodal emotion recognition to extract features, fuse information, and classify \nemotional states. \n3. LLM-enabled therapeutic dialogue to generate supportive, empathetic, and \nregulation-oriented responses. \n4. Closed-loop emotional regulation where user feedback is continuously sensed, \ninterpreted, and used to adapt future responses. \nThe paper’s proposed architecture includes four modules: contextual multimodal profiling, \nemotion expression, emotion recognition, and emotion regulation. This framework aims to \nmove AER systems from static, rule-based interaction toward adaptive, real-time, \npersonalized support. \nCore Contributions and Novelty \nThe paper’s main contribution is its integrated review of a field that has previously been \nstudied in fragmented ways. Earlier reviews often focused separately on AI for mental \nhealth, multimodal emotion recognition, psychotherapy chatbots, or LLMs in healthcare. \nThis review attempts to connect all of these areas into a unified perspective on AER \nsystems. \nIts key contributions are: \nUnified perspective on multimodal sensing and LLMs: \nThe paper explicitly studies how sensing technologies and LLM-based dialogue systems \ncan be combined for emotional regulation, rather than treating them as separate research \nareas. \nCoverage of sensing modalities and datasets: \nIt reviews visual, auditory, physiological, behavioral, and contextual modalities, along with \nrepresentative datasets such as IEMOCAP, MAHNOB-HCI, DEAP, CMU-MOSEI, RAVDESS, \nMELD, and HEU.'),
#  Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T13:05:42+02:00', 'source': '../data/pdf_files/Multimodal Sensing-Enabled Large Language Models for Automated Emotional Regulation.pdf', 'file_path': '../data/pdf_files/Multimodal Sensing-Enabled Large Language Models for Automated Emotional Regulation.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T13:05:42+02:00', 'trapped': '', 'modDate': "D:20260509130542+02'00'", 'creationDate': "D:20260509130542+02'00'", 'page': 2}, page_content='Review of fusion and recognition methods: \nThe paper discusses feature-level, decision-level, hybrid, and model-level fusion \nstrategies, as well as classifiers and deep learning methods such as CNNs, LSTMs, \ntransformers, SVMs, KNNs, and random forests. \nDiscussion of LLM-enabled therapeutic interaction: \nIt reviews how GPT-3.5, GPT-4, ChatGPT, LLaMA2, DeepSeek, BlenderBot, Baichuan-13B-\nchat, and Video-LLaMA can support emotional dialogue, CBT-style support, cognitive \nreappraisal, and multimodal psychological assistance. \nProposed conceptual AER architecture: \nA major novelty is the proposed four-module framework involving contextual multimodal \nprofiling, emotion expression, emotion recognition, and emotion regulation, supported by a \nclosed-loop perception–memory–reasoning–action cycle. \nCritical focus on challenges: \nThe review gives strong attention to privacy, safety, bias, interpretability, crisis escalation, \nclinical validation, accountability, and governance. \nData/Database & Task Setup \nThe paper is a review and therefore does not introduce a new dataset or conduct a new \nempirical experiment. Instead, it surveys representative datasets used in multimodal \nemotion recognition and related AER research. \nThe reviewed data types include: \nVideo / Visual Data: Facial expressions, gaze, body movement, head pose, facial action \nunits, posture, and visual behavior. \nAudio Data: Speech tone, pitch, intensity, prosody, pauses, acoustic features, and spoken \nlanguage content. \nText Data: User utterances, conversation transcripts, emotional language, clinical notes, \nand chatbot interactions. \nPhysiological Signals: ECG, PPG, EDA/GSR, EEG, EMG, EOG, respiration, skin \ntemperature, heart-rate variability, and blood volume pulse. \nBehavioral / Contextual Data: GPS trajectories, smartphone use, communication logs, \naccelerometer-based activity, device usage, VR interaction logs, and IoT-based contextual \nsignals. \nRepresentative datasets discussed include eNTERFACE, IEMOCAP, MAHNOB-HCI, AFEW, \nDEAP, CMU-MOSEI, RAVDESS, MELD, and HEU. These datasets support tasks such as \ncategorical emotion classification, valence–arousal prediction, depression recognition, \nmultimodal sentiment analysis, and conversational emotion recognition. \nThe task setup generally follows a pipeline: multimodal input collection, feature extraction, \nmultimodal fusion, emotion classification, and response generation or regulation strategy'),
#  Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T13:05:42+02:00', 'source': '../data/pdf_files/Multimodal Sensing-Enabled Large Language Models for Automated Emotional Regulation.pdf', 'file_path': '../data/pdf_files/Multimodal Sensing-Enabled Large Language Models for Automated Emotional Regulation.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T13:05:42+02:00', 'trapped': '', 'modDate': "D:20260509130542+02'00'", 'creationDate': "D:20260509130542+02'00'", 'page': 3}, page_content='selection. In AER, the final task is not only to recognize emotion but also to use that \nrecognition to guide adaptive therapeutic or supportive interaction. \nMethodology \nThe paper uses a literature review methodology. It synthesizes research papers, technical \nreports, theoretical frameworks, datasets, models, and system prototypes related to \nmultimodal sensing, emotion recognition, LLMs, and automated emotional regulation. \nThe methodology can be summarized as follows: \n1. Review of existing AER approaches: The authors trace the evolution of automated \nemotional support from early rule-based chatbots such as ELIZA to CBT-based systems \nsuch as Woebot and modern LLM-powered systems. \n2. Review of unimodal and multimodal sensing: The paper compares visual, auditory, \nphysiological, and behavioral/contextual modalities, highlighting their strengths and \nweaknesses. It argues that unimodal systems are limited by noise, occlusion, ambiguity, \ncultural differences, and weak generalization. \n3. Review of emotion recognition pipelines: The paper describes a standard three-stage \nmultimodal emotion recognition pipeline: multimodal sensing, multimodal information \nfusion, and emotional classification. \n4. Review of multimodal fusion strategies: It explains feature-level fusion, decision-level \nfusion, hybrid fusion, and model-level fusion, discussing trade-offs related to robustness, \nmissing data, computational complexity, and real-time deployment. \n5. Review of LLM-based therapeutic dialogue: The paper surveys LLM use in emotional \nsupport conversations, CBT-style interventions, cognitive reappraisal, RAG-based \ninformational support, counselor–client simulation, and multi-agent therapeutic systems. \n6. Conceptual architecture design: The authors propose a unified framework for \nmultimodal LLM-based AER, composed of contextual multimodal profiling, emotion \nexpression, emotion recognition, and emotion regulation modules. \n7. Challenge analysis: The methodology concludes with a structured analysis of \ntechnical, ethical, practical, and systemic challenges, including privacy, bias, \ninterpretability, crisis response, clinical safety, and evaluation standards. \nModel Details \nThe paper reviews several model families and their use cases rather than implementing \none specific model. \nCNNs: Used for visual emotion recognition, physiological signal classification, and feature \nextraction from structured sensor data. \nRNNs / LSTMs: Used for sequential emotional signal modeling, especially EEG, speech, \nand conversational emotion recognition.'),
#  Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T13:05:42+02:00', 'source': '../data/pdf_files/Multimodal Sensing-Enabled Large Language Models for Automated Emotional Regulation.pdf', 'file_path': '../data/pdf_files/Multimodal Sensing-Enabled Large Language Models for Automated Emotional Regulation.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T13:05:42+02:00', 'trapped': '', 'modDate': "D:20260509130542+02'00'", 'creationDate': "D:20260509130542+02'00'", 'page': 4}, page_content='Transformers: Used for self-supervised multimodal representation learning, crossmodal \nfusion, and sequence modeling across physiological, audio, visual, and textual streams. \nSVM, KNN, Decision Trees, Random Forests: Used as conventional machine learning \nclassifiers for physiological and multimodal emotion recognition tasks. \nGraph-MFN: Discussed in relation to CMU-MOSEI for multimodal sentiment and emotion \nanalysis in the wild. \nGPT-3.5 / GPT-4 / ChatGPT: Used for supportive conversation, CBT-style management, \nemotional co-regulation, counselor–client simulation, and context-aware response \ngeneration. \nLLaMA2: Discussed as an efficient and scalable LLM option for emotional understanding \nand potential resource-constrained deployment. \nDeepSeek: Mentioned as an emerging LLM with potential strengths in fine-grained \nemotional understanding and customized dialogue. \nBlenderBot: Reviewed in multimodal emotional support conversation systems as a \nconversational model baseline or component. \nVideo-LLaMA / GPT-4V: Used or discussed for multimodal understanding involving text, \nimage, audio, and video. \nBaichuan-13B-chat: Reviewed in relation to multimodal psychological adaptation and \nprofiling systems. \nRAG-enhanced LLMs: Used to ground therapeutic responses in trusted external \nknowledge, such as CBT, DBT, mindfulness, or clinically vetted scripts. \nLoRA / lightweight fine-tuning: Discussed as a way to adapt general LLMs to specialized \nemotional recognition or therapeutic dialogue tasks. \nEvaluation & Metrics \nBecause the paper is a review, it does not conduct a single unified evaluation. Instead, it \nsummarizes evaluation strategies and metrics used across existing studies. \nFor emotion recognition, the reviewed metrics include: \nAccuracy: Used for categorical emotion classification, such as recognizing happiness, \nsadness, anger, fear, disgust, surprise, or neutral states. \nF1-score: Used when class imbalance exists, especially in emotion classification and \nsentiment/emotion recognition tasks. \nWeighted Accuracy: Used in multimodal datasets such as CMU-MOSEI to account for \nclass distribution differences. \nCorrelation / ICC: Used for dimensional emotion prediction, such as valence and arousal \nestimation in in-the-wild settings. \nValence–Arousal Scores: Used to evaluate continuous affective state prediction, \nespecially in datasets such as DEAP and MAHNOB-HCI.'),
#  Document(metadata={'producer': 'Microsoft® Word LTSC', 'creator': 'Microsoft® Word LTSC', 'creationdate': '2026-05-09T13:05:42+02:00', 'source': '../data/pdf_files/Multimodal Sensing-Enabled Large Language Models for Automated Emotional Regulation.pdf', 'file_path': '../data/pdf_files/Multimodal Sensing-Enabled Large Language Models for Automated Emotional Regulation.pdf', 'total_pages': 6, 'format': 'PDF 1.7', 'title': '', 'author': 'Reza Azari', 'subject': '', 'keywords': '', 'moddate': '2026-05-09T13:05:42+02:00', 'trapped': '', 'modDate': "D:20260509130542+02'00'", 'creationDate': "D:20260509130542+02'00'", 'page': 5}, page_content='For LLM-based therapeutic systems, the paper discusses evaluation more cautiously. \nRelevant evaluation dimensions include perceived empathy, response safety, clinical \nappropriateness, emotional alignment, conversational quality, adherence to therapeutic \nprotocols, hallucination risk, and crisis-handling ability. \nThe paper emphasizes that laboratory emotion recognition systems often achieve stronger \nperformance than systems tested in the wild. It also stresses that standardized \nbenchmarks for clinical safety, long-term efficacy, fairness, and real-world emotional \nregulation remain underdeveloped. \nPractical Impact & Future Works \nThe practical impact of this review is significant for the design of future AI-based mental \nhealth and emotional support systems. By integrating multimodal sensing with LLMs, \nfuture AER systems could provide more personalized, continuous, context-aware, and \nadaptive emotional support. Such systems may be useful in mental healthcare, education, \nworkplace well-being, elderly care, social robotics, VR therapy, and human–computer \ninteraction. \nHowever, the paper is careful not to overstate current readiness. It argues that multimodal \nLLM-based AER remains a nascent field. Real-world deployment requires stronger \nevidence of clinical effectiveness, robust privacy protection, crisis escalation protocols, \nbias mitigation, and transparent governance. \nFuture research directions include: \n• \nDeveloping larger, more diverse, and ecologically valid multimodal emotional \ndatasets. \n• \nImproving robustness to missing, noisy, or low-quality sensor data. \n• \nAdvancing interpretable and clinically trustworthy emotion recognition models. \n• \nBuilding culturally adaptive and personalized emotional regulation systems. \n• \nGrounding LLM responses in evidence-based therapeutic frameworks using RAG \nand clinical knowledge bases. \n• \nEstablishing standardized benchmarks for safety, fairness, efficacy, and emotional \nalignment. \n• \nDesigning strong crisis detection and human handoff mechanisms. \n• \nUsing privacy-preserving learning methods such as federated learning, differential \nprivacy, and on-device processing. \n• \nConducting longitudinal clinical studies to test real-world effectiveness and risks. \nOverall, the paper provides a valuable, timely, and comprehensive review of how \nmultimodal sensing and LLMs may reshape automated emotional regulation, while clearly \nidentifying the technical, ethical, and clinical barriers that must be addressed before these \nsystems can be safely and responsibly deployed.')]
